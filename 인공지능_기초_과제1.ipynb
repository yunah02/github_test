# %% [markdown]
# <a href="https://colab.research.google.com/github/yunah02/github_test/blob/main/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_%EA%B8%B0%EC%B4%88_%EA%B3%BC%EC%A0%9C1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
#데이터 저장 위치
data_home = 'https://github.com/dknife/ML/raw/main/data/'
lin_data = pd.read_csv(data_home+'pollution.csv') #데이터 파일 이름
print(lin_data)
# Out:
#        input  pollution
# 0   0.240557   4.858750
# 1   0.159731   4.471091
# 2   0.108295   4.341897
# 3   0.233770   3.586844
# 4   0.283235   3.678243
# ..       ...        ...
# 95  0.070824   4.851617
# 96  0.055300   4.912696
# 97  0.138229   5.516441
# 98  0.007205   5.661260
# 99  0.290294   3.169049
#
# [100 rows x 2 columns]

# %%
lin_data.plot(kind = 'scatter', x = 'input', y = 'pollution')
# Out:
# <Axes: xlabel='input', ylabel='pollution'>

# %%
w, b = 1,1
x0, x1 = 0.0, 1.0
def h(x, w, b):  #가설에 따라 값을 계산하는 함수
    return w*x + b

# 데이터(산포도)와 가설(직선)을 비교
lin_data.plot(kind = 'scatter', x= 'input', y='pollution')
plt.plot([x0, x1], [h(x0, w, b), h(x1, w, b)])

# %%
w, b = -3, 6
x0, x1 = 0.0, 1.0

#새로운 파라미터로 가설(직선)과 데이터(산포도) 비교
lin_data.plot(kind = 'scatter', x = 'input', y= 'pollution')
plt.plot([x0, x1], [h(x0, w, b), h(x1, w, b)])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error as mse

# 5개의 점의 x, y좌표값
x = np.array([1, 4.5, 9, 10,13])
y = np.array([0, 0.2, 2.5, 5.4, 7.3])

w_list = np.arange(1.0, 0.2, -0.1)
for w in list(w_list):  #w를 바꾸어가며 예측치와 정답의 오차 비교
   y_hat = w * x
   print('w = {:.1f}, 평균제곱 오차: {:.2f}'.format(w, mse(y_hat, y)))
# Out:
# w = 1.0, 평균제곱 오차: 23.08
# w = 0.9, 평균제곱 오차: 15.86
# w = 0.8, 평균제곱 오차: 10.13
# w = 0.7, 평균제곱 오차: 5.89
# w = 0.6, 평균제곱 오차: 3.13
# w = 0.5, 평균제곱 오차: 1.85
# w = 0.4, 평균제곱 오차: 2.06
# w = 0.3, 평균제곱 오차: 3.75

# %%
import matplotlib.pyplot as plt
import numpy as np

#닥스훈트의 길이와 높이 데이터
dach_length = [77, 78, 85, 83, 73, 77, 73, 80]
dach_height = [25, 28, 29, 30, 21, 22, 17, 35]
#사모예드의 길이와 높이 데이터
samo_length = [75, 77, 86, 86, 79, 83, 83, 88]
samo_height = [56, 57, 50, 53, 60, 53, 49, 61]

plt.scatter(dach_length, dach_height, c='red', label='Dachshund')
plt.scatter(samo_length, samo_height, c='blue',marker='^', label='Samoyed')

plt.xlabel('Length')
plt.ylabel('Height')
plt.title("Dog size")
plt.legend(loc='upper left')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#닥스훈트의 길이와 높이 데이터
dach_length = [77, 78, 85, 83, 73, 77, 73, 80]
dach_height = [25, 28, 29, 30, 21, 22, 17, 35]
#사모예드의 길이와 높이 데이터
samo_length = [75, 77, 86, 86, 79, 83, 83, 88]
samo_height = [56, 57, 50, 53, 60, 53, 49, 61]

plt.scatter(dach_length, dach_height, c='red', label='Dachshund')
plt.scatter(samo_length, samo_height, c='blue',marker='^', label='Samoyed')

plt.xlabel('Length')
plt.ylabel('Height')
plt.title("Dog size")
plt.legend(loc='upper left')

newdata_length = [79]    #새로운 데이터의 길이
newdata_height = [35]    #새로운 데이터의 높이

#....코드 생략
#새 데이터의 표식은 오각형(pentagon)으로 설정하고, 레이블은 new Data로
plt.scatter(newdata_length, newdata_height, s=100,
            marker='p', c='green', label='new Data')

# %%
import matplotlib.pyplot as plt
import numpy as np

#닥스훈트의 길이와 높이 데이터
dach_length = [77, 78, 85, 83, 73, 77, 73, 80]
dach_height = [25, 28, 29, 30, 21, 22, 17, 35]
#사모예드의 길이와 높이 데이터
samo_length = [75, 77, 86, 86, 79, 83, 83, 88]
samo_height = [56, 57, 50, 53, 60, 53, 49, 61]

plt.scatter(dach_length, dach_height, c='red', label='Dachshund')
plt.scatter(samo_length, samo_height, c='blue',marker='^', label='Samoyed')

plt.xlabel('Length')
plt.ylabel('Height')
plt.title("Dog size")
plt.legend(loc='upper left')

newdata_length = [79]    #새로운 데이터의 길이
newdata_height = [35]    #새로운 데이터의 높이

#....코드 생략
#새 데이터의 표식은 오각형(pentagon)으로 설정하고, 레이블은 new Data로
plt.scatter(newdata_length, newdata_height, s=100,
            marker='p', c='green', label='new Data')

d_data = np.colum_stack((dach_length, dach_height))
d_label = np.zeros(len(d_data))  #닥스훈트는 0으로 레이블링

s_data = np.column_stack((samo_length, samo_height))
s_label = np.ones(len(s_data))   #사모예드는 1로 레이블링

newdata = [[79, 35]]

dog_classes = {0:'Dachund', 1:'Samoyed'}

k = 3    #k를 3으로 두고 KNN 분류기를 만들어 보자
knn.fit(dogs, labels)
y_pred = knn.predict(newdata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-ab2d531fa0be> in <cell line: 27>()
#      25             marker='p', c='green', label='new Data')
#      26
# ---> 27 d_data = np.colum_stack((dach_length, dach_height))
#      28 d_label = np.zeros(len(d_data))  #닥스훈트는 0으로 레이블링
#      29
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     309             return Tester
#     310
# --> 311         raise AttributeError("module {!r} has no attribute "
#     312                              "{!r}".format(__name__, attr))
#     313
#
# AttributeError: module 'numpy' has no attribute 'colum_stack'

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

#닥스훈트의 몸 길이와 몸 높이
dach_length = [77, 78, 85, 83, 73, 77, 73, 80]
dach_height = [25, 28, 19, 30, 21, 22, 17, 35]

#사모예드의 몸 길이와 몸 높이
samo_length = [75, 77, 86, 86, 79, 83, 83, 88]
samo_height = [56, 57, 50, 53, 60, 53, 49, 61]

d_data = np.column_stack((dach_length, dach_height))
d_label = np.zeros(len(d_data))           #닥스훈트는 0으로 레이블링
s_data = np.column_stack((samo_length, samo_height))
s_label = np.ones(len(s_data))            #사모예드는 1로 레이블링

newdata = [[79, 35]]

dogs = np.concatenate((d_data, s_data))
labels = np.concatenate((d_label, s_label))

dogs_classes = {0:'Dachshund', 1:'Samoyed'}

k = 3,    #k를 3으로 두고 KNN 분류기를 만들어 보자
knn = KNeighborsClassifier(n_neighbors = k)
knn.fit(dogs, labels)
y_pred = knn.predict(newdata)
print('데이터', newdata, ', 판정 결과:', dog_classes[y_pred[0]])



###이거 안나옴 다시 꼭 하기,, 하
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-40-8826c4918f16> in <cell line: 27>()
#      25 k = 3,    #k를 3으로 두고 KNN 분류기를 만들어 보자
#      26 knn = KNeighborsClassifier(n_neighbors = k)
# ---> 27 knn.fit(dogs, labels)
#      28 y_pred = knn.predict(newdata)
#      29 print('데이터', newdata, ', 판정 결과:', dog_classes[y_pred[0]])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     211             The fitted k-nearest neighbors classifier.
#     212         """
# --> 213         self._validate_params()
#     214
#     215         return self._fit(X, y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_params(self)
#     598         accepted constraints.
#     599         """
# --> 600         validate_parameter_constraints(
#     601             self._parameter_constraints,
#     602             self.get_params(deep=False),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      95                 )
#      96
# ---> 97             raise InvalidParameterError(
#      98                 f"The {param_name!r} parameter of {caller_name} must be"
#      99                 f" {constraints_str}. Got {param_val!r} instead."
#
# InvalidParameterError: The 'n_neighbors' parameter of KNeighborsClassifier must be an int in the range [1, inf) or None. Got (3,) instead.

# %%
from sklearn.datasets import load_iris

iris = load_iris()
iris.data[:5]    #최초 5개 데이터의 값을 출력
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
import pandas as pd

iris_df = pd.DataFrame(iris.data, columns-iris.feature_names)
iris_df['target'] = pd.Series(iris.target)
iris_df.head()

#왜 틀리냐...ㅜㅠ 모르겠네,, 하,,, 좀 돌아가라ㅠㅠㅠ 울고 싶다 왜 안될까? 뭐가 잘못된거니???
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-f1a3c84da778> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 iris_df = pd.DataFrame(iris.data, columns-iris.feature_names)
#       4 iris_df['target'] = pd.Series(iris.target)
#       5 iris_df.head()
#
# NameError: name 'columns' is not defined

# %%
x = iris_df.iloc[:, :4]
y = iris_df.iloc[:, -1]

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

def iris_knn(X, y, k):
    X_train,X_test,y_train,y_test =train_test_split(X, y, test_size=0.3)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    return metrics.accuracy_score(y_test, y_pred)

k = 3
scores = iris_knn(X, y, k)
print('n_neighbors가 {0:d}일때 정확도: {1,.3f}'.format(k, scores))

##나중에 다시 해보자 왜 안될까? 뭔가가 빠졌을 가능성이 높겠찌 ㅎ핳핫
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-961e0094b1b4> in <cell line: 1>()
# ----> 1 x = iris_df.iloc[:, :4]
#       2 y = iris_df.iloc[:, -1]
#       3
#       4 from sklearn.model_selection import train_test_split
#       5 from sklearn.neighbors import KNeighborsClassifier
#
# NameError: name 'iris_df' is not defined

# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier

iris = load_iris()
k = 3
knn = KNeighborsClassifier(n_neighbors = k)
knn.fit(iris.data,iris.target)

#이건 몰까?
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
classes = {0:'setosa', 1:'versicolor', 2:'virginica'}

#새로운 데이터를 제시 해보자.
x = [[4, 2, 1.3, 0.4],
    [4, 3, 3.2, 2.2]]
y = knn.predict(x)

print('{} 특성을 가지는 품종: {}'.format(X[0], classes[y[0]]))
print('{} 특성을 가지는 품종: {}'.format(x[1], classes[y[1]]))
#뭔가 이상한가보다 오히려 좋아ㅡ 쉬우면 노잼이지 뭐 ㅋ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-429844ffd153> in <cell line: 8>()
#       6 y = knn.predict(x)
#       7
# ----> 8 print('{} 특성을 가지는 품종: {}'.format(X[0], classes[y[0]]))
#       9 print('{} 특성을 가지는 품종: {}'.format(x[1], classes[y[1]]))
#
# NameError: name 'X' is not defined

# %%
y_pred_all = knn.predict(iris.data)
scores = metrics.accuracy_score(iris.target, y_pred_all)
print('n_neighbors가 {0:d}일때 정확도: {1:.3f}'.fornmat(k, scores))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-99596ad67a4e> in <cell line: 3>()
#       1 y_pred_all = knn.predict(iris.data)
#       2 scores = metrics.accuracy_score(iris.target, y_pred_all)
# ----> 3 print('n_neighbors가 {0:d}일때 정확도: {1:.3f}'.fornmat(k, scores))
#
# AttributeError: 'str' object has no attribute 'fornmat'

# %%
import matplotlib.pyplot as plt
plt.hist2d(iris.target, y_pred_all, bins=(3,3), cmap=plt.cm.jet)
# Out:
# (array([[50.,  0.,  0.],
#         [ 0., 47.,  3.],
#         [ 0.,  3., 47.]]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <matplotlib.collections.QuadMesh at 0x7e8d1362e500>)

# %%
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(iris.target, y_pred_all)
conf_mat
# Out:
# array([[50,  0,  0],
#        [ 0, 47,  3],
#        [ 0,  3, 47]])

# %%
def classifier_A(lengths, heights): #입력값에 관계없이 'Samoyed'를 반환
    return 'Samoyed'

# %%
import numpy as np
import matplotlib.pyplot as plt

# 사모예드와 닥스훈트의 길이, 높이 데이터는 중복되어 생략한다
# 개의 길이와 높이를 각각 ndarray 형태로 만든다
dog_length = np.array(dach_length + samo_length)  #리스트를 이어 ndarray로
dog_height = np.array(dach_height + samo_height)  #리스트를 이어 ndrarray로

dog_data = np.column_stack((dog_length, dog_height))

plt.title("Dog data without label")
plt.scatter(dog_length, dog_height)

# %%
from sklearn import cluster

def kmeans_predict_plot(x, k):
    model = cluster.KMeans(n_clusters=k)
    model.fit(x)
    labels = model.predict(x)
    colors = np.array(['red', 'green', 'blue', 'magenta'])
    plt.suptitle('k-Means clustering, k={}'.format(k))
    plt.scatter(X[:, 0], X[:, 1], color=colors[labels])

kmeans_predict_plot(dog_data, k = 2 )


#나중에 다시 하기 왜 코드가 뭐가 이상할까  5주차 68p
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-8acb0c25690a> in <cell line: 11>()
#       9     plt.scatter(X[:, 0], X[:, 1], color=colors[labels])
#      10
# ---> 11 kmeans_predict_plot(dog_data, k = 2 )
#
# <ipython-input-70-8acb0c25690a> in kmeans_predict_plot(x, k)
#       7     colors = np.array(['red', 'green', 'blue', 'magenta'])
#       8     plt.suptitle('k-Means clustering, k={}'.format(k))
# ----> 9     plt.scatter(X[:, 0], X[:, 1], color=colors[labels])
#      10
#      11 kmeans_predict_plot(dog_data, k = 2 )
#
# NameError: name 'X' is not defined

# %%
kmeans_predict_plot(dog_data, k = 3) # 3개의 군집 생성
kmeans_predict_plot(dog_data, k = 4) # 4개의 군집 생성
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-ce8195cb8442> in <cell line: 1>()
# ----> 1 kmeans_predict_plot(dog_data, k = 3) # 3개의 군집 생성
#       2 kmeans_predict_plot(dog_data, k = 4) # 4개의 군집 생성
#
# <ipython-input-70-8acb0c25690a> in kmeans_predict_plot(x, k)
#       7     colors = np.array(['red', 'green', 'blue', 'magenta'])
#       8     plt.suptitle('k-Means clustering, k={}'.format(k))
# ----> 9     plt.scatter(X[:, 0], X[:, 1], color=colors[labels])
#      10
#      11 kmeans_predict_plot(dog_data, k = 2 )
#
# NameError: name 'X' is not defined
